# %% [raw]
# Question1) Define the z-statistic and explain its relationship to the standard normal distribution. How is the
# z-statistic used in hypothesis testing

# %%
'''Answer1)

Definition of the Z-Statistic:
The z-statistic (or z-score) is a standardized value that measures the number of standard deviations a data point is from 
the population mean.

Relationship to the Standard Normal Distribution:
The z-statistic transforms data into a standard normal distribution with:

Mean = 0
Standard deviation = 1
This transformation allows us to use the standard normal distribution table (z-table) to find probabilities
associated with specific z-scores.
​
Use of Z-Statistic in Hypothesis Testing:
State the Hypotheses:

Null Hypothesis (Ho): Assumes no effect or no difference 
Alternative Hypothesis (Ha):Assumes an effect or difference.

Calculate the Z-Statistic:
Use the formula for z depending on whether you’re dealing with a population or sample.

Find the p-Value:
Use the z-score to find the probability from the z-table.
The p-value indicates the probability of observing a value as extreme as, or more extreme than, the sample statistic under Ho.
​
Decision Rule:
Compare the p-value to the significance level (𝛼):
If 𝑝≤𝛼:
p≤α, reject 𝐻o.
If 𝑝>𝛼
p>α, fail to reject 𝐻o

​Alternatively, compare the z-statistic to critical values (e.g.,−1.96 and 1.96
1.96 for a 5% significance level in a two-tailed test).'''

# %% [raw]
# Question2) What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?

# %%
'''Answer:
The p-value (probability value) is a measure used in hypothesis testing to assess the strength of the
evidence against the null hypothesis (𝐻o).
It quantifies the probability of observing a test statistic (or something more extreme) assuming that the null hypothesis is true.

Key Points:
Small p-value: Indicates stronger evidence against the null hypothesis.
Large p-value: Suggests weaker evidence against the null hypothesis.

The P-Value Used in Hypothesis Testing
State the Hypotheses:
Ho: Null hypothesis (e.g., no effect, no difference).
𝐻𝑎: Alternative hypothesis (e.g., an effect, a difference)

Interpretation of a Small P-Value (e.g., 0.01):
A p-value of 0.01 indicates only a 1% probability of obtaining a test statistic as extreme as the observed
one if Ho is true.
This provides strong evidence to reject the null hypothesis.
If the chosen significance level is 𝛼=0.05, a p-value of 0.01 is less than 0.05, leading to rejection of 𝐻o'''
​

# %% [raw]
# Question3) Compare and contrast the binomial and Bernoulli distributions.

# %%
#answer3)

"""a)Binomial Distribution:
Definition:	Models the number of successes in a fixed number of independent Bernoulli trials.
Parameters:	n-Number of trials,p- Probability of success in each trial
Support (Possible Values):	Discrete values from 0,1,2,…,n.
The Binomial distribution deals with the total number of successes in multiple
independent Bernoulli trials.
Number of Trials: A fixed number of trials (n).
Example:
Toss a coin 10 times:
Count the number of heads (successes) in 10 trials.
Probability of success p for each trial."""

# %% [markdown]
# ![binomial-distribution-formula.png](attachment:e60bb651-cf05-428d-b8ad-ecf57e99cef2.png)

# %%
"""
b)Bernoulli Distribution:
Definition:Models the outcome of a single Bernoulli trial (success/failure)
Parameters: p: Probability of success in the single trial
The Bernoulli distribution deals with a single experiment or trial.
Number of Trials: Only one trial.
The outcome is binary, 0 or 1.
Example:

Bernoulli Distribution:

Toss a coin once:
Success (heads) = 1, Failure (tails) = 0.
Probability p of success

# %% [markdown]
# ![bernoliDistribution1.jpg](attachment:1738d95a-3814-40ea-85be-cbb60a662643.jpg)

# %% [markdown]
# Question 4) Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution

# %%
'''Answer 4)
Conditions is the binomial distribution:
The experiment consists of a predetermined number of trials.
Each trial has only two possible outcomes: success or failure (e.g., heads or tails in a coin toss).
The outcome of any trial does not affect the outcome of other trials
The variable of interest is the number of successes in n trials.

Relationship Between the Binomial and Bernoulli Distributions:
The Bernoulli distribution models the outcome of a single trial.
and binomial distribution models the total number of successes in multiple independent Bernoulli trials.

Bernoulli distribution has a single parameter p, representing the probability of success in one trial.
Binomial distribution has two parameters:
n= Number of independent trials.
p=Probability of success in each trial.'''

# %% [markdown]
# PMF:
# Bernoulli PMF Formula:
# ![bernoliDistribution1.jpg](attachment:1738d95a-3814-40ea-85be-cbb60a662643.jpg)
# Binomial Formula:
# ![binomial-distribution-formula.png](attachment:fee8eb60-e10c-4997-bb39-32d1f2e09382.png)

# %% [markdown]
# Question5)What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?

# %%
'''Answer 5)
The Poisson distribution is a discrete probability distribution that models the number of events occurring 
within a fixed interval of time, space, or other continuous domains, under certain conditions

key properties of the Poisson distribution:
The Poisson distribution describes the probability of a count of events (e.g., 0, 1, 2, 3... events) in a fixed interval.
The distribution is characterized by a single parameter, λ (lambda), which represents:
The average rate (mean) of events occurring in the given interval λ>0.
The mean (μ) and variance (σ **2) of the Poisson distribution are both equal to λ:

When is The Poisson Distribution Appropriate:
The events occur randomly in time or space.
The occurrence of one event does not affect the probability of another event occurring.
The events occur at a constant mean rate (λ) over the fixed interval.
The number of events in non-overlapping intervals is independent.
Example of use case:
Traffic Flow:
Modeling the number of cars passing through a toll booth per hour.'''

# %% [markdown]
# Probability Mass Function (PMF):
# The probability of observing x event is given by:
# ![OIP.jpg](attachment:5e82d1cd-2933-4d56-9287-f7e7e1f4be8f.jpg)

# %% [raw]
# Question6) Define the terms "probability distribution" and "probability density function" (PDF). How does a
# PDF differ from a probability mass function (PMF)

# %%
'''Answer 6)
"probability distribution":
A probability distribution describes how the values of a random variable are distributed. 
It specifies the probabilities of different outcomes for a random variable. Depending on whether
the random variable is discrete or continuous, probability distributions are represented differently:

a)Discrete Random Variable: Probability Mass Function (PMF).
b)Continuous Random Variable: Probability Density Function (PDF).

"Probability Density Function (PDF)":
A Probability Density Function (PDF) is used for continuous random variables. It describes the likelihood
of the random variable taking on a particular value within a continuous range

a)Probability Mass Function (PMF): 
Used for Discrete random Varialbles.It gives probability of excact  outcomes P(X=x).
It is sum ∑P(X=x)=1.for example --> Rolling dice ;discrete outcomes:1,2,3,4,5,6

b)Probability Mass Function(PDF):
used for Continuous random variables.Represents density; probability for interval 
via integration.
it is integral ∫𝑓(𝑥)𝑑𝑥=1
for Example--> Heights of people (continuous range of values)'''

# %% [raw]
# Question7) Explain the Central Limit Theorem (CLT) with example

# %%
'''Answer 7)
The Central Limit Theorem (CLT) states that when you repeatedly draw large samples from a population, the distribution of the 
sample mean will approach a normal distribution, regardless of the population's original distribution, provided the 
sample size is sufficiently large.

For Example:
Suppose you are analyzing the time it takes for customers to complete an online purchase.
The time follows a skewed distribution (e.g., exponential), with a mean time of μ=10 minutes and a standard deviation of 
σ=5 minutes.

Steps:

Take Repeated Samples:
You take random samples of 50 customer purchase times (n=50).

Compute Sample Means:
For each sample, calculate the average time (X𝑛).

Distribution of Sample Means:
According to the CLT, the distribution of these sample means will be approximately normal, 
even though the original distribution of individual purchase times is skewed.

Result:
The sample mean distribution will have:
Mean: μ=10 minutes.
Standard deviation: 𝜎=5/square root of 50 =0.71 min.

​Visualization of CLT
Original data distribution: Skewed or non-normal.
Distribution of sample means (as n increases): Approaches a normal curve.'''

# %% [raw]
# Question8) Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?

# %%
'''Answer 8)

A) z-score (or standard score) measures how many standard deviations a data point is from the
population mean. It is used when the population's standard deviation (σ) is known.
Follows the standard normal distribution N(0,1).
Used for large sample sizes (n≥30) when σ is known.

When to Use Z-Scores:

1)Population Standard Deviation (σ) Known:
If you know the population standard deviation, use a z-score.
Large Sample Sizes (n≥30):
The sample size is large enough for the sample standard deviation to 
approximate the population standard deviation.'''

# %% [markdown]
# Formula:![how-to-solve-for-and-interpret-z-scores-introductory-statistics-2-638.webp](attachment:272e9a96-95fb-4f3b-b401-b61980e07568.webp)

# %% [raw]
# '''B) T-Scores
# A t-score is used when the population standard deviation (σ) is unknown
# and is estimated using the sample standard deviation (s). The t-distribution is more
# spread out and has heavier tails than the normal distribution, especially for small sample sizes.
#
# Follows a t-distribution with n−1 degrees of freedom (df=n−1).
# The shape of the t-distribution depends on the sample size:
# Small n: More spread out, heavier tails.
# Large n: Approximates the standard normal distribution.
#
# When to Use T-Scores:
# a)Population Standard Deviation (σ) Unknown:
# If σ is unknown, and you estimate it using the sample standard deviation, use a t-score.
# b)Small Sample Sizes (n<30):
# The t-distribution compensates for the increased variability when working with small samples.
# Formula:
# Where
# x̄ = sample mean
# μ0 = population mean
# s = sample standard deviation
# n = sample size

# %% [markdown]
# Formula:
#
# ![t-score.jpg](attachment:ec143376-dede-4191-ad5a-ea369d008bfb.jpg)sizesize

# %% [markdown]
# Question 9)
# Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to
# reject the null hypothesis?
#
#  Task: Write Python code to calculate the z-score and p-value for the given data.
#
# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing

# %%
# Answer 9)

import scipy.stats as stats #zcritical approach
import numpy as np
# as per question :
mu=105
x=100
sigma=15
n=25 
alpha=0.05
# where h0=105 and Ha!=100
zscore=(mu-x)/(x/np.sqrt(50))
print ('the zscore is',zscore)
# Out:
# the zscore is 0.3535533905932738

# %%
#for zcritical scipy.stats
zcritical = stats.norm.ppf(1-alpha)
zcritical
# Out:
# 1.6448536269514722

# %%
if zscore > zcritical:
    print("Reject the null hypothesis")
else:
    print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %%
#using bscipy.stats pvalue approach
p_value = 1-stats.norm.cdf(zscore)

if p_value <= 0.05:
    print("reject the null hypothesis")
else:
    print("fail to reject null hypothesis")
# Out:
# fail to reject null hypothesis

# %% [raw]
# Question 10) Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?
#
# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.
#
# Objective: Understand the properties of a binomial distribution and verify them through simulation

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n_trials = 10
p_success = 0.6
n_samples = 1000

# Generate 1000 samples from a binomial distribution
data = np.random.binomial(n=n_trials, p=p_success, size=n_samples)

# Plot the distribution
plt.hist(data, bins=range(n_trials + 2), align='left', edgecolor='black', rwidth=0.8)
plt.title('Binomial Distribution (n=10, p=0.6, 1000 samples)')
plt.xlabel('Number of successes')
plt.ylabel('Frequency')
plt.xticks(range(n_trials + 1))
plt.show()

# Calculate the mean and variance of the generated data
mean_simulated = np.mean(data)
variance_simulated = np.var(data)

# Theoretical mean and variance
mean_theoretical = n_trials * p_success
variance_theoretical = n_trials * p_success * (1 - p_success)

# Print results
print(f"Simulated Mean: {mean_simulated}")
print(f"Simulated Variance: {variance_simulated}")
print(f"Theoretical Mean: {mean_theoretical}")
print(f"Theoretical Variance: {variance_theoretical}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Simulated Mean: 6.065
# Simulated Variance: 2.490775
# Theoretical Mean: 6.0
# Theoretical Variance: 2.4000000000000004
